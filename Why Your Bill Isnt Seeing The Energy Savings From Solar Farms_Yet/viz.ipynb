# %%
# %%
import pandas as pd
import requests

EIA_KEY = "YOUR EIA KEY"  
START_YEAR = "2001"
END_YEAR = "2024"
STATE = "TX"

# --- 1. GENERATION DATA ---
GEN_URL = "https://api.eia.gov/v2/electricity/electric-power-operational-data/data/"
gen_params = {
    "api_key": EIA_KEY,
    "frequency": "annual",
    "data[0]": "generation",
    "facets[location][]": STATE,
    "facets[sectorid][]": "98",         
    "facets[fueltypeid][]": ["ALL", "SUN"],  
    "start": START_YEAR,
    "end": END_YEAR,
    "sort[0][column]": "period",
    "sort[0][direction]": "asc",
    "length": 5000 
}

gen_req = requests.get(GEN_URL, params=gen_params)
gen_df = pd.DataFrame(gen_req.json()['response']['data'])
gen_df['generation'] = pd.to_numeric(gen_df['generation'], errors='coerce')
gen_df['period'] = pd.to_datetime(gen_df['period'], format='%Y').dt.year

fuel_pivot = gen_df.pivot_table(index='period', columns='fueltypeid', values='generation', aggfunc='sum').fillna(0)
fuel_pivot['pct_solar'] = (fuel_pivot['SUN'] / fuel_pivot['ALL']) * 100
tx_generation = fuel_pivot[['pct_solar']].reset_index()

# --- 2. RETAIL DATA (Simplified for Price Only) ---
PRICE_URL = "https://api.eia.gov/v2/electricity/retail-sales/data/"
price_params = {
    "api_key": EIA_KEY,
    "frequency": "annual",
    "data[0]": "price", # Just pulling the raw cents/kWh now
    "facets[stateid][]": STATE,
    "facets[sectorid][]": "RES",  
    "start": START_YEAR,
    "end": END_YEAR,
    "sort[0][column]": "period",
    "sort[0][direction]": "asc",
    "length": 5000 
}

price_req = requests.get(PRICE_URL, params=price_params)
price_df = pd.DataFrame(price_req.json()['response']['data'])

price_df['price'] = pd.to_numeric(price_df['price'], errors='coerce')
price_df['period'] = pd.to_datetime(price_df['period'], format='%Y').dt.year

tx_retail = price_df[['period', 'price']].rename(
    columns={'price': 'res_price_cents_kwh'}
).copy()

# --- 3. MASTER MERGE ---
tx_final_df = pd.merge(tx_generation, tx_retail, on='period', how='inner')
tx_final_df['pct_solar'] = tx_final_df['pct_solar'].round(2)
tx_final_df['res_price_cents_kwh'] = tx_final_df['res_price_cents_kwh'].round(2)
# Out:
# --- Texas Master Dataset (2001-2024) ---
#     period  pct_solar  res_price_cents_kwh
# 0     2001      -0.00                 8.86
# 1     2002       0.00                 8.05
# 2     2003       0.00                 9.16
# 3     2004       0.00                 9.73
# 4     2005       0.00                10.93
# 5     2006       0.00                12.86
# 6     2007       0.00                12.34
# 7     2008       0.00                13.03
# 8     2009       0.00                12.38
# 9     2010       0.00                11.60
# 10    2011       0.01                11.08
# 11    2012       0.03                10.98
# 12    2013       0.04                11.35
# 13    2014       0.07                11.86
# 14    2015       0.10                11.56
# 15    2016       0.18                10.99
# 16    2017       0.53                11.01
# 17    2018       0.74                11.20
# 18    2019       0.99                11.76
# 19    2020       1.98                11.71
# 20    2021       3.39                12.11
# 21    2022       4.64                13.76
# 22    2023       5.58                14.46
# 23    2024       7.74                14.94

# %%
# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Apply your BTT Master Style
try:
    plt.style.use('btt_style') 
except:
    pass 

fig, ax1 = plt.subplots()

color_solar = '#E6A01D' 
color_price = '#1E3A8A' # Swapped the variable name for clarity

# --- AXIS 1: Solar Percentage (Left) ---
ax1.plot(tx_final_df['period'], tx_final_df['pct_solar'], color=color_solar, label='Utility-Scale Solar')
ax1.set_ylabel("% of Texas Grid USS", color=color_solar, fontweight='bold', labelpad=15)
ax1.tick_params(axis='y', labelcolor=color_solar)
ax1.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))
ax1.set_ylim(0, 10) 

# --- AXIS 2: Retail Electricity Price (Right) ---
ax2 = ax1.twinx()
# Swapped to the new retail price column
ax2.plot(tx_final_df['period'], tx_final_df['res_price_cents_kwh'], color=color_price, label='Retail Price')

# Updated label to reflect cents per kWh
ax2.set_ylabel('Texas REP (cents/kWh)', color=color_price, fontweight='bold', labelpad=15)
ax2.tick_params(axis='y', labelcolor=color_price)

# Formatting the ticks to show the cent symbol with one decimal place
ax2.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

# Snapped the limits to hug Texas historical retail prices 
ax2.set_ylim(6, 16) 

# --- FORMATTING & CLEANUP ---
# Re-snapped the limits to perfectly hug a 24-year timeline
ax1.set_xlim(1999, 2026) 

# Generate a perfectly equidistant 4-year interval (2000, 2004, ... 2024)
custom_ticks = list(range(2001, 2026, 4))
ax1.set_xticks(custom_ticks)

# Rotate labels 45 degrees and align them perfectly to the tick marks
plt.setp(ax1.get_xticklabels(), rotation=45, ha='right', rotation_mode='anchor')

# Dropped the pad slightly since the rotation naturally creates breathing room
ax1.tick_params(axis='x', pad=10)

# --- THE TITLE ---
# Tweaked the title to reflect the shift from Bills to Prices
#fig.suptitle("USS vs. Texans' Power Bills", fontsize=46, fontweight='bold')

# Force the outer border thickness directly on the figure object
fig.patch.set_linewidth(4) 

fig.savefig("fig1.png", dpi=600)

# %%
import gridstatus


# Initialize the ERCOT ISO class
ercot = gridstatus.Ercot()

# 1. Pull historical hourly fuel mix from the EIA archive
# You can grab a free key in 30 seconds at eia.gov
eia = gridstatus.EIA(api_key="m3sfdl54PXmaMuJcludgJXHrzWJbOlwjVpRFh4Gm")

generation_df = eia.get_dataset(
    dataset="electricity/rto/fuel-type-data", # Removed the trailing /data
    start="2026-07-11",
    end="2026-07-13", 
    facets={"respondent": ["ERCO"]} 
)

# 2. Pull the Real-Time Settlement Point Prices (SPP) for yesterday
# The market MUST be explicitly defined as "REAL_TIME_15_MIN"
pricing_df = ercot.get_spp(date="2026-07-11", market="REAL_TIME_15_MIN")

# 3. Filter the pricing data for the general Hub Average
# (Otherwise you will be plotting thousands of individual neighborhood nodes)
hub_pricing_df = pricing_df[pricing_df["Location"] == "HB_HUBAVG"]

# Add this to your existing pull cell
demand_df = ercot.get_load(date="2026-07-11")
# Out:
# 2026-07-18 11:47:38 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=12301&_1784389658
# 2026-07-18 11:47:38 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=12301&_1784389658 with {}
# 2026-07-18 11:47:39 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249176779
# 2026-07-18 11:47:39 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249172834
# 2026-07-18 11:47:40 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249168909
# 2026-07-18 11:47:41 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249165821
# 2026-07-18 11:47:42 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249161852
# 2026-07-18 11:47:42 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249158281
# 2026-07-18 11:47:43 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249154441
# 2026-07-18 11:47:44 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249150799
# 2026-07-18 11:47:44 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249144149
# 2026-07-18 11:47:44 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249142194
# 2026-07-18 11:47:45 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249138418
# 2026-07-18 11:47:46 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249135130
# 2026-07-18 11:47:47 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249127745
# 2026-07-18 11:47:47 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249127132
# 2026-07-18 11:47:48 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249123643
# 2026-07-18 11:47:48 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249120337
# 2026-07-18 11:47:49 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249114660
# 2026-07-18 11:47:49 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249112748
# 2026-07-18 11:47:49 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249108886
# 2026-07-18 11:47:50 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249105493
# 2026-07-18 11:47:50 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249101142
# 2026-07-18 11:47:51 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249097216
# 2026-07-18 11:47:51 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249093622
# 2026-07-18 11:47:52 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249090123
# 2026-07-18 11:47:53 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249086040
# 2026-07-18 11:47:53 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249082441
# 2026-07-18 11:47:54 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249078936
# 2026-07-18 11:47:54 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249075331
# 2026-07-18 11:47:54 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249071276
# 2026-07-18 11:47:55 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249067619
# 2026-07-18 11:47:55 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249064040
# 2026-07-18 11:47:56 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249060624
# 2026-07-18 11:47:57 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249056846
# 2026-07-18 11:47:57 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249053102
# 2026-07-18 11:47:58 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249049566
# 2026-07-18 11:47:59 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249046107
# 2026-07-18 11:47:59 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249042157
# 2026-07-18 11:47:59 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249038207
# 2026-07-18 11:48:00 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249034558
# 2026-07-18 11:48:01 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249028187
# 2026-07-18 11:48:02 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249024883
# 2026-07-18 11:48:02 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249020875
# 2026-07-18 11:48:03 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249017540
# 2026-07-18 11:48:03 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249013995
# 2026-07-18 11:48:04 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249009928
# 2026-07-18 11:48:04 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249006355
# 2026-07-18 11:48:05 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1249001523
# 2026-07-18 11:48:05 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248997942
# 2026-07-18 11:48:05 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248994178
# 2026-07-18 11:48:06 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248990718
# 2026-07-18 11:48:06 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248985031
# 2026-07-18 11:48:06 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248983413
# 2026-07-18 11:48:07 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248979591
# 2026-07-18 11:48:08 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248975968
# 2026-07-18 11:48:08 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248972120
# 2026-07-18 11:48:09 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248968429
# 2026-07-18 11:48:10 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248964513
# 2026-07-18 11:48:10 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248960729
# 2026-07-18 11:48:10 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248954794
# 2026-07-18 11:48:11 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248950499
# 2026-07-18 11:48:12 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248944687
# 2026-07-18 11:48:12 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248938290
# 2026-07-18 11:48:13 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248935022
# 2026-07-18 11:48:13 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248930103
# 2026-07-18 11:48:14 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248924636
# 2026-07-18 11:48:14 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248920991
# 2026-07-18 11:48:15 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248917226
# 2026-07-18 11:48:15 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248913616
# 2026-07-18 11:48:16 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248909678
# 2026-07-18 11:48:17 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248906192
# 2026-07-18 11:48:17 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248902068
# 2026-07-18 11:48:18 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248897713
# 2026-07-18 11:48:19 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248892146
# 2026-07-18 11:48:19 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248887911
# 2026-07-18 11:48:20 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248884232
# 2026-07-18 11:48:20 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248880789
# 2026-07-18 11:48:21 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248873744
# 2026-07-18 11:48:22 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248869919
# 2026-07-18 11:48:23 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248857044
# 2026-07-18 11:48:23 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248862822
# 2026-07-18 11:48:24 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248859163
# 2026-07-18 11:48:25 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248849866
# 2026-07-18 11:48:26 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248851866
# 2026-07-18 11:48:26 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248848087
# 2026-07-18 11:48:27 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248844316
# 2026-07-18 11:48:27 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248840476
# 2026-07-18 11:48:28 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248837006
# 2026-07-18 11:48:28 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248833218
# 2026-07-18 11:48:29 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248829745
# 2026-07-18 11:48:30 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248821404
# 2026-07-18 11:48:31 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248822252
# 2026-07-18 11:48:31 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248818657
# 2026-07-18 11:48:32 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248814903
# 2026-07-18 11:48:33 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248810997
# 2026-07-18 11:48:34 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248807239
# 2026-07-18 11:48:34 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1248803680
# 2026-07-18 11:48:35 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=10008&_1784389715
# 2026-07-18 11:48:35 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=10008&_1784389715 with {}
# 2026-07-18 11:48:35 - INFO - Fetching https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1250353236
# 2026-07-18 11:48:36 - INFO - Fetching https://www.ercot.com/content/cdr/html/20260711_actual_loads_of_forecast_zones.html

# %%
# --- THE FIX: Standardize the EIA timestamp column to match ERCOT ---
generation_df = generation_df.rename(columns={'Interval Start': 'Time'})

# 1. Break the link to the master dataframe to avoid copy warnings
hub_pricing_df = hub_pricing_df.copy()

# 2. Convert both to datetime objects
generation_df['Time'] = pd.to_datetime(generation_df['Time'])
hub_pricing_df['Time'] = pd.to_datetime(hub_pricing_df['Time'])

# 3. Safely convert to Central Time ONLY if they haven't been stripped yet
if generation_df['Time'].dt.tz is not None:
    generation_df['Time'] = generation_df['Time'].dt.tz_convert('US/Central').dt.tz_localize(None)

if hub_pricing_df['Time'].dt.tz is not None:
    hub_pricing_df['Time'] = hub_pricing_df['Time'].dt.tz_convert('US/Central').dt.tz_localize(None)

# --- NEW STEP: Snap the EIA generation window perfectly to the ERCOT pricing window ---
min_time = hub_pricing_df['Time'].min()
max_time = hub_pricing_df['Time'].max()

generation_df = generation_df[
    (generation_df['Time'] >= min_time) & 
    (generation_df['Time'] <= max_time)
]

# 4. Apply the 2-hour centered moving average to smooth out the wholesale price volatility
hub_pricing_df['SPP_Smoothed'] = hub_pricing_df['SPP'].rolling(window=8, center=True).mean()

# Convert to datetime and strip timezone for demand
demand_df['Time'] = pd.to_datetime(demand_df['Time'])
if demand_df['Time'].dt.tz is not None:
    demand_df['Time'] = demand_df['Time'].dt.tz_convert('US/Central').dt.tz_localize(None)

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Apply your custom newsletter style file
plt.style.use('btt_style')

# Set up the figure and the first axis 
fig, ax1 = plt.subplots()

# Define colors
color_gen = '#E6A01D' 
color_price = '#1E3A8A' 
color_demand = '#6B7280'

# ---------------------------------------------------------
# 1. LEFT AXIS: Solar Generation 
# ---------------------------------------------------------
ax1.plot(generation_df['Time'], generation_df['Solar'], color=color_gen, linewidth=3)
ax1.set_ylabel('Texas USS Generation (MW)', color=color_gen, labelpad=15)
ax1.tick_params(axis='y', labelcolor=color_gen)
ax1.grid(True, alpha=0.3)
ax1.set_ylim(-4000,80000)

# ---------------------------------------------------------
# 2. RIGHT AXIS (Standard): Wholesale Price
# ---------------------------------------------------------
ax2 = ax1.twinx()
ax2.plot(hub_pricing_df['Time'], hub_pricing_df['SPP_Smoothed'] / 10, color=color_price, linewidth=3)
ax2.set_ylabel('Texas WEP (cents/kWh)', color=color_price, labelpad=15)
ax2.tick_params(axis='y', labelcolor=color_price)
ax2.grid(False)
ax2.axhline(0, color='black', linewidth=1, linestyle='--', alpha=0.5)

# ---------------------------------------------------------
# 3. RIGHT AXIS (Offset): Total Demand
# ---------------------------------------------------------
ax3 = ax1.twinx()
# Push this axis outward by 15% so it doesn't overlap the pricing axis
ax3.spines['right'].set_position(('axes', 1.15)) 

ax3.fill_between(demand_df['Time'], demand_df['Load'], color=color_demand, alpha=0.15)
ax3.set_ylabel('Total Demand (MW)', color=color_demand, labelpad=15)
ax3.tick_params(axis='y', labelcolor=color_demand)

# ---------------------------------------------------------
# Formatting & Export
# ---------------------------------------------------------
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%#I%p'))
ax1.xaxis.set_major_locator(mdates.HourLocator(interval=3))

fig.patch.set_linewidth(4) 



# bbox_inches='tight' guarantees the 3rd axis label isn't cropped in the png
fig.savefig("fig2.png", bbox_inches='tight')
plt.show()
